# %%
import pandas as pd

# %%
# General Method
grades = pd.Series([90, 80, 50, 60])

total = 0
for i in grades:
    total += i

average = (total / len(grades))
print(average)
# Out:
# 70.0

# %%
# Vectorized Method
import numpy as np
total = np.sum(grades)

average = (total / len(grades))
print(average)
# Out:
# 70.0

# %%
numbers = pd.Series(np.random.randint(0,1000,10000))

numbers.tail()
# Out:
# 9995    994
# 9996    963
# 9997    727
# 9998    423
# 9999    352
# dtype: int32

# %%
# %%timeit -n 100
total = 0
for number in numbers:
    total+=number

total/len(numbers)
# Out:
# 1.1 ms ± 144 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
total = np.sum(numbers)
total/len(numbers)
# Out:
# 35.9 μs ± 7.37 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
numbers.head()
# Out:
# 0    509
# 1    468
# 2    555
# 3    811
# 4    702
# dtype: int32

# %%
numbers += 2
numbers.head()
# Out:
# 0    511
# 1    470
# 2    557
# 3    813
# 4    704
# dtype: int32

# %%
for label, value in numbers.items():
    numbers.at[label] = value+2

numbers.head()
# Out:
# 0    523
# 1    482
# 2    569
# 3    825
# 4    716
# dtype: int32

# %%
# %%timeit -n 10
# we'll create a blank new series of items to deal with
s = pd.Series(np.random.randint(0,1000,1000))
# And we'll just rewrite our loop from above.
for label, value in s.items():
    s.at[label]= value+2
# Out:
# 14.4 ms ± 1.67 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
# We need to recreate a series
s = pd.Series(np.random.randint(0,1000,1000))
# And we just broadcast with +=
s+=2
# Out:
# 140 μs ± 25.6 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
