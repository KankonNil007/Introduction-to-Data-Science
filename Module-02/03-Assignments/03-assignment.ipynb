# %% [markdown]
# ## Question 3
# It would be interesting to see if there is any evidence of a link between vaccine effectiveness and sex of the child. Calculate the ratio of the number of children who contracted chickenpox but were vaccinated against it (at least one varicella dose) versus those who were vaccinated but did not contract chicken pox. Return results by sex.
#
# *This function should return a dictionary in the form of (use the correct numbers):*
# ```
#     {"male":0.2,
#     "female":0.4}
# ```
#
# Note: To aid in verification, the `chickenpox_by_sex()['female']` value the autograder is looking for starts with the digits `0.0077`.

# %% [markdown]
# ### Solution Explanation
#
# This problem requires applying chained logic gates to find ratio relationships across two unique cohorts (Males/Females).
#
# - `[(df['P_NUMVRC'] >= 1) & (df['HAD_CPOX'].isin([1, 2]))]` generates a mask keeping only individuals who specifically took `1` or more doses of the vaccine, while discarding those with missing/unknown chickenpox logs (`[1,2]` implies Yes/No).
# - Setting the main `vax` subset, we slice the filtered population into Male (`SEX == 1`) and Female (`SEX == 2`) sub-frames.
# - Finally, we run `len()` counts over each gender subset for positive diagnoses (`HAD_CPOX == 1`) and negative diagnoses (`HAD_CPOX == 2`), returning the ratio division to map the metric.

# %%
def chickenpox_by_sex():
    import pandas as pd
    df = pd.read_csv('datasets/NISPUF17.csv')
    
    # Baseline filter: Vaccine >= 1 dose & valid chickenpox diagnosis status
    vax = df[(df['P_NUMVRC'] >= 1) & (df['HAD_CPOX'].isin([1, 2]))]
    
    # Extract the male subset to calculate its ratios
    male_vax = vax[vax['SEX'] == 1]
    male_cpox = len(male_vax[male_vax['HAD_CPOX'] == 1])
    male_nocpox = len(male_vax[male_vax['HAD_CPOX'] == 2])
    
    # Extract the female subset to calculate its ratios
    female_vax = vax[vax['SEX'] == 2]
    female_cpox = len(female_vax[female_vax['HAD_CPOX'] == 1])
    female_nocpox = len(female_vax[female_vax['HAD_CPOX'] == 2])
    
    return {
        "male": male_cpox / male_nocpox if male_nocpox else 0,
        "female": female_cpox / female_nocpox if female_nocpox else 0
    }

# %%
assert len(chickenpox_by_sex())==2, "Return a dictionary with two items, the first for males and the second for females."
